# %% [markdown]
# # Medicijn hergebruik voor kanker

# %% [markdown]
# ## Intro
# Het ontwikkelen van nieuwe medicijnen kost veel geld en tijd, terwijl het niet altijd nodig is om die helemaal opnieuw te ontwikkelen. We beschikken namelijk al over een breed scala aan goedgekeurde medicijnen. Bij colorectale kanker is er sprake van verhoogde genetische instabiliteit, veroorzaakt door hoge LINE-1 transposonactiviteit, wat een kenmerk is van de ziekte. Ieder heeft ongeveer 100 actieve, maar zwaar gemethyleerde LINE-1's in het genoom. Deze functioneren door middel van reverse transcriptase (RT), afkomstig van hun retrovirale achtergrond. Hierdoor is het mogelijk retrovirale virusremmers, zoals HIV-remmers, te gebruiken als medicijn om deze activiteit te onderdrukken. Dit wordt al toegepast in sommige kankertherapieën en is een voorbeeld van medicijn hergebruik. Het biedt een kans om te onderzoeken of er wellicht andere medicijnen bestaan die potentieel toegepast kunnen worden in de behandeling van kanker.

# %% [markdown]
# # Doel
#
# Het doel van dit project is om te onderzoeken of er al mogelijke medicijnen bestaan die van toepassing kunnen zijn bij de behandeling van kanker. Dit gaan we onderzoeken door middel van RNA count data van kanker en niet kanker. Hier worden de differential expressed genes (DEG) van afgeleid, om vervolgens een medicijnen netwerk op te zetten op basis van deze DEG. Dit zal kunnen leiden tot een netwerk model van potentiële medicijnen.
#
# Als een proof of concept gaan we inzoomen op 1 kankersoort. Welke dit zal worden is afhankelijk van de dataset die we vinden.

# %% [markdown]
# # Project Imports

# %%
import pandas as pd, numpy as np
import networkx as nx
from scipy import stats
from statsmodels.stats.multitest import multipletests
from pyvis.network import Network

# %% [markdown]
# # Exploratieve Data Analysis
#
# ## DEG zoeken
# Starten met het inladen van de data die uitgepakt staat in `data/`. De data komt van [https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE62944](https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE62944). De link bevat meer informatie over de afkomst van de data. De data bevat de count data van gezond en tumor weefsel, deze zijn verbonden door middel van een id, hiermee ook te koppelen aan een type tumor.

# %%
# Het normal.txt-bestand inladen en het tonen van de eerste paar regels
normal_data = pd.read_csv("data/GSM1697009_06_01_15_TCGA_24.normal_Rsubread_FeatureCounts.txt", sep="\t", index_col=0)
print("Normal data")
print(normal_data.head())

# Het cancer.txt-bestand inladen en het tonen van de eerste paar regels
cancer_data = pd.read_csv("data/GSM1536837_06_01_15_TCGA_24.tumor_Rsubread_FeatureCounts.txt", sep="\t", index_col=0)
print("\n Cancer data")
print(cancer_data.head())
# Out:
# Normal data
#              TCGA-06-0675-11A-32R-A36H-07  TCGA-06-0678-11A-32R-A36H-07  \
# 1/2-SBSRNA4                            48                            25
# A1BG                                  206                           112
# A1BG-AS1                               87                            44
# A1CF                                    8                             2
# A2LD1                                 138                            99
#
#              TCGA-06-0680-11A-32R-A36H-07  TCGA-06-0681-11A-41R-A36H-07  \
# 1/2-SBSRNA4                            36                            28
# A1BG                                  223                           361
# A1BG-AS1                              122                           120
# A1CF                                    5                             1
# A2LD1                                 127                           110
#
#              TCGA-06-AABW-11A-31R-A36H-07  TCGA-22-4593-11A-01R-1820-07  \
# 1/2-SBSRNA4                            23                            31
# A1BG                                  573                           243
# A1BG-AS1                               69                            78
# A1CF                                    2                             1
# A2LD1                                 144                           495
#
#              TCGA-22-4609-11A-01R-2125-07  TCGA-22-5471-11A-01R-1635-07  \
# 1/2-SBSRNA4                            26                            25
# A1BG                                  211                           121
# A1BG-AS1                               64                            61
# A1CF                                    1                             4
# A2LD1                                 231                           168
#
#              TCGA-22-5472-11A-11R-1635-07  TCGA-22-5478-11A-11R-1635-07  ...  \
# 1/2-SBSRNA4                            28                            20  ...
# A1BG                                  143                           163  ...
# A1BG-AS1                               63                            75  ...
# A1CF                                    1                             1  ...
# A2LD1                                 305                           264  ...
#
#              TCGA-W5-AA2X-11A-11R-A41I-07  TCGA-W5-AA30-11A-11R-A41I-07  \
# 1/2-SBSRNA4                            14                             6
# A1BG                                63878                         88979
# A1BG-AS1                              484                           553
# A1CF                                 9400                          8699
# A2LD1                                 230                           227
#
#              TCGA-W5-AA31-11A-11R-A41I-07  TCGA-W5-AA34-11A-11R-A41I-07  \
# 1/2-SBSRNA4                             2                             9
# A1BG                                65575                         70809
# A1BG-AS1                              530                           480
# A1CF                                17254                         14975
# A2LD1                                 639                          1117
#
#              TCGA-WA-A7GZ-11A-11R-A34R-07  TCGA-X7-A8D6-11A-22R-A42C-07  \
# 1/2-SBSRNA4                            13                            65
# A1BG                                   42                           418
# A1BG-AS1                               15                           129
# A1CF                                    4                             2
# A2LD1                                 151                           309
#
#              TCGA-X7-A8D7-11A-11R-A42C-07  TCGA-Y8-A8RY-11A-11R-A37K-07  \
# 1/2-SBSRNA4                           137                            90
# A1BG                                 1241                           130
# A1BG-AS1                              231                            43
# A1CF                                    3                            23
# A2LD1                                 293                           563
#
#              TCGA-YB-A89D-11A-11R-A36G-07  TCGA-ZU-A8S4-11A-11R-A41I-07
# 1/2-SBSRNA4                            25                             5
# A1BG                                  306                         82446
# A1BG-AS1                               32                           582
# A1CF                                  159                         10378
# A2LD1                                 223                           371
#
# [5 rows x 741 columns]
#
#  Cancer data
#              TCGA-02-0047-01A-01R-1849-01  TCGA-02-0055-01A-01R-1849-01  \
# 1/2-SBSRNA4                            30                            32
# A1BG                                  277                           889
# A1BG-AS1                               38                            47
# A1CF                                    1                             3
# A2LD1                                 118                           183
#
#              TCGA-02-2483-01A-01R-1849-01  TCGA-02-2485-01A-01R-1849-01  \
# 1/2-SBSRNA4                            51                            35
# A1BG                                  784                           162
# A1BG-AS1                               51                            27
# A1CF                                    1                             1
# A2LD1                                  91                           319
#
#              TCGA-02-2486-01A-01R-1849-01  TCGA-04-1331-01A-01R-1569-13  \
# 1/2-SBSRNA4                            26                            87
# A1BG                                  203                           884
# A1BG-AS1                               25                           156
# A1CF                                    1                             5
# A2LD1                                 339                           228
#
#              TCGA-04-1332-01A-01R-1564-13  TCGA-04-1337-01A-01R-1564-13  \
# 1/2-SBSRNA4                            29                           176
# A1BG                                  139                           725
# A1BG-AS1                               25                           181
# A1CF                                    5                             8
# A2LD1                                 159                           458
#
#              TCGA-04-1338-01A-01R-1564-13  TCGA-04-1341-01A-01R-1564-13  ...  \
# 1/2-SBSRNA4                            19                            45  ...
# A1BG                                  153                          1239  ...
# A1BG-AS1                               17                            46  ...
# A1CF                                    4                             6  ...
# A2LD1                                 126                           250  ...
#
#              TCGA-ZP-A9D1-01A-11R-A38B-07  TCGA-ZP-A9D2-01A-11R-A38B-07  \
# 1/2-SBSRNA4                             7                            16
# A1BG                                86364                          1770
# A1BG-AS1                              315                            22
# A1CF                                 9750                          8139
# A2LD1                                 334                           690
#
#              TCGA-ZP-A9D4-01A-11R-A37K-07  TCGA-ZQ-A9CR-01A-11R-A39E-31  \
# 1/2-SBSRNA4                            18                            16
# A1BG                                69815                           176
# A1BG-AS1                              442                            17
# A1CF                                12569                           410
# A2LD1                                 247                           140
#
#              TCGA-ZS-A9CD-01A-11R-A37K-07  TCGA-ZS-A9CE-01A-11R-A37K-07  \
# 1/2-SBSRNA4                             5                            16
# A1BG                                79301                        252753
# A1BG-AS1                              401                           709
# A1CF                                 5768                         14115
# A2LD1                                 378                           977
#
#              TCGA-ZS-A9CF-01A-11R-A38B-07  TCGA-ZS-A9CF-02A-11R-A38B-07  \
# 1/2-SBSRNA4                            34                            76
# A1BG                                17086                          7819
# A1BG-AS1                              153                            79
# A1CF                                11587                         17483
# A2LD1                                 539                           712
#
#              TCGA-ZS-A9CG-01A-11R-A37K-07  TCGA-ZX-AA5X-01A-11R-A42T-07
# 1/2-SBSRNA4                            11                            15
# A1BG                                23141                           108
# A1BG-AS1                              144                            34
# A1CF                                12948                             1
# A2LD1                                 464                            93
#
# [5 rows x 9264 columns]

# %% [markdown]
# Doormiddel van pandas is de data eenvoudig ingelezen. De rows bestaan uit genen en de kolommen uit id's. Nu het identificeren van welke tumor de counts data is. We maken een functie om labels uit de bestanden te halen.

# %%
# chat-gpt
def process_cancer_data(file_path):
    """
        Processes a file with labels and cancer types and returns a dictionary.

        Args:
            file_path (str): Path to the file.

        Returns:
            dict: A dictionary with cancer types as keys and lists of labels as values.
    """
    cancer_dict = {}

    with open(file_path, 'r') as file:
        for line in file:
            label, cancer_type = line.strip().split('\t')
            if cancer_type not in cancer_dict:
                cancer_dict[cancer_type] = []
            cancer_dict[cancer_type].append(label)

    return cancer_dict

# %% [markdown]
# Functie toepassen.

# %%
normal_data_labels = process_cancer_data("data/GSE62944_06_01_15_TCGA_24_Normal_CancerType_Samples.txt")
print(normal_data_labels.keys())
# Out:
# dict_keys(['BLCA', 'LUAD', 'LIHC', 'BRCA', 'LUSC', 'UCEC', 'PAAD', 'HNSC', 'STAD', 'COAD', 'KIRC', 'PRAD', 'KICH', 'THCA', 'CESC', 'READ', 'CHOL', 'PCPG', 'KIRP', 'ESCA', 'SKCM', 'GBM', 'SARC', 'THYM'])

# %% [markdown]
# En nu voor de kankerdata.

# %%
cancer_data_labels = process_cancer_data("data/GSE62944_01_27_15_TCGA_20_CancerType_Samples.txt")
print(cancer_data_labels.keys())
# Out:
# dict_keys(['LGG', 'STAD', 'BRCA', 'LIHC', 'KIRP', 'OV', 'KIRC', 'LUAD', 'PRAD', 'COAD', 'BLCA', 'KICH', 'THCA', 'UCEC', 'HNSC', 'LUSC', 'GBM', 'SKCM', 'READ', 'LAML'])

# %%
def print_dict_contents(my_dict):
    """
    Prints the count of values for each key in a dictionary.

    Parameters:
        my_dict (dict): A dictionary where each key maps to a collection of values (e.g., list, set, tuple).

    Returns:
        None
    """
    for key, values in my_dict.items():
        count = len(values)
        print(f"Key: {key}, Count: {count}")

print("Normal Data:")
print_dict_contents(normal_data_labels)
print("\nCancer Data:")
print_dict_contents(cancer_data_labels)
# Out:
# Normal Data:
# Key: BLCA, Count: 19
# Key: LUAD, Count: 59
# Key: LIHC, Count: 50
# Key: BRCA, Count: 113
# Key: LUSC, Count: 51
# Key: UCEC, Count: 35
# Key: PAAD, Count: 4
# Key: HNSC, Count: 44
# Key: STAD, Count: 37
# Key: COAD, Count: 41
# Key: KIRC, Count: 72
# Key: PRAD, Count: 52
# Key: KICH, Count: 25
# Key: THCA, Count: 59
# Key: CESC, Count: 3
# Key: READ, Count: 10
# Key: CHOL, Count: 9
# Key: PCPG, Count: 3
# Key: KIRP, Count: 32
# Key: ESCA, Count: 13
# Key: SKCM, Count: 1
# Key: GBM, Count: 5
# Key: SARC, Count: 2
# Key: THYM, Count: 2
#
# Cancer Data:
# Key: LGG, Count: 528
# Key: STAD, Count: 146
# Key: BRCA, Count: 1082
# Key: LIHC, Count: 212
# Key: KIRP, Count: 226
# Key: OV, Count: 344
# Key: KIRC, Count: 540
# Key: LUAD, Count: 514
# Key: PRAD, Count: 423
# Key: COAD, Count: 468
# Key: BLCA, Count: 273
# Key: KICH, Count: 66
# Key: THCA, Count: 506
# Key: UCEC, Count: 536
# Key: HNSC, Count: 481
# Key: LUSC, Count: 490
# Key: GBM, Count: 170
# Key: SKCM, Count: 373
# Key: READ, Count: 164
# Key: LAML, Count: 164

# %% [markdown]
# Nu gaan we van de data een subset maken op basis van kankertype. In de contents van de data hierboven is er het meesten van `BCRA`; We kiezen daarom voor de `BCRA`, dat borstkanker representeert.

# %%
cancer_key = "BRCA"
# Making BRCA labels
normal_BRCA_labels = normal_data_labels[cancer_key]
cancer_BRCA_labels = cancer_data_labels[cancer_key]
print(f"Normal BRCA label: {len(normal_BRCA_labels)} | Cancer BRCA label: {len(cancer_BRCA_labels)}")

# Subsetting data to BRCA key
print(f"Normal dataset length: {len(normal_data.columns)} | Cancer dataset length: {len(cancer_data.columns)}")
normal_data_subset = normal_data[normal_BRCA_labels]
cancer_data_subset = cancer_data[cancer_BRCA_labels]
print(f"After subsetting\nNormal dataset length: {len(normal_data_subset.columns)} | Cancer dataset length: {len(cancer_data_subset.columns)}")
# Out:
# Normal BRCA label: 113 | Cancer BRCA label: 1082
# Normal dataset length: 741 | Cancer dataset length: 9264
# After subsetting
# Normal dataset length: 113 | Cancer dataset length: 1082

# %% [markdown]
# De counts moeten nog genormaliseerd worden. Dit wordt met een log2 transformatie toegepast op de dataset. Een tpm is ook nog een overwogen optie, alleen voldoet voor dit korte onderzoek de log2.

# %%
def log_transform(expression_data):
    """
    Applies a log2(x + 1) transformation to an expression matrix.

    Args:
        expression_data (pd.DataFrame): Raw counts data where rows are genes and columns are samples.

    Returns:
        pd.DataFrame: Log-transformed expression data.
    """
    return np.log2(expression_data + 1)

# %% [markdown]
# Nu het toepassen van de normalisering.

# %%
normal_data_log = log_transform(normal_data_subset)
cancer_data_log = log_transform(cancer_data_subset)
print(normal_data_log.head())
print(cancer_data_log.head())
# Out:
#              TCGA-BH-A0DV-11A-22R-A12P-07  TCGA-BH-A0BC-11A-22R-A089-07  \
# 1/2-SBSRNA4                      5.930737                      5.247928
# A1BG                             7.451211                      6.794416
# A1BG-AS1                         6.584963                      4.584963
# A1CF                             2.807355                      2.000000
# A2LD1                            7.960002                      7.888743
#
#              TCGA-BH-A0BM-11A-12R-A089-07  TCGA-AC-A2FB-11A-13R-A17B-07  \
# 1/2-SBSRNA4                      6.209453                      5.584963
# A1BG                             8.082149                      7.948367
# A1BG-AS1                         6.022368                      6.426265
# A1CF                             2.584963                      1.584963
# A2LD1                            7.459432                      8.252665
#
#              TCGA-A7-A13E-11A-61R-A12P-07  TCGA-BH-A0BA-11A-22R-A19E-07  \
# 1/2-SBSRNA4                      4.906891                      5.357552
# A1BG                             6.426265                      7.375039
# A1BG-AS1                         5.129283                      5.930737
# A1CF                             1.584963                      2.807355
# A2LD1                            8.113742                      7.693487
#
#              TCGA-BH-A1FC-11A-32R-A13Q-07  TCGA-E9-A1R7-11A-42R-A14M-07  \
# 1/2-SBSRNA4                      4.169925                      5.000000
# A1BG                             7.033423                      5.554589
# A1BG-AS1                         5.781360                      5.321928
# A1CF                             1.584963                      1.000000
# A2LD1                            7.820179                      7.988685
#
#              TCGA-BH-A0BQ-11A-33R-A115-07  TCGA-AC-A2FF-11A-13R-A17B-07  ...  \
# 1/2-SBSRNA4                      5.906891                      5.954196  ...
# A1BG                             7.179909                      8.361944  ...
# A1BG-AS1                         6.087463                      7.055282  ...
# A1CF                             1.584963                      3.321928  ...
# A2LD1                            8.092757                      8.463524  ...
#
#              TCGA-BH-A1FB-11A-33R-A13Q-07  TCGA-BH-A0DO-11A-22R-A12D-07  \
# 1/2-SBSRNA4                      5.523562                      6.087463
# A1BG                             7.700440                      7.781360
# A1BG-AS1                         6.820179                      6.209453
# A1CF                             1.000000                      2.584963
# A2LD1                            7.409391                      8.005625
#
#              TCGA-BH-A0H7-11A-13R-A089-07  TCGA-BH-A0DD-11A-23R-A12P-07  \
# 1/2-SBSRNA4                      5.977280                      4.087463
# A1BG                             8.317413                      5.584963
# A1BG-AS1                         6.303781                      4.321928
# A1CF                             1.584963                      0.000000
# A2LD1                            8.139551                      8.016808
#
#              TCGA-AC-A23H-11A-12R-A157-07  TCGA-BH-A0C3-11A-23R-A12P-07  \
# 1/2-SBSRNA4                      5.906891                      6.614710
# A1BG                             6.845490                      7.960002
# A1BG-AS1                         6.044394                      6.988685
# A1CF                             3.000000                      2.807355
# A2LD1                            8.076816                      7.607330
#
#              TCGA-E2-A1IG-11A-22R-A144-07  TCGA-BH-A18S-11A-43R-A12D-07  \
# 1/2-SBSRNA4                      4.857981                      4.754888
# A1BG                             6.965784                      7.636625
# A1BG-AS1                         5.832890                      6.507795
# A1CF                             2.000000                      2.321928
# A2LD1                            7.562242                      7.266787
#
#              TCGA-BH-A0BJ-11A-23R-A089-07  TCGA-BH-A0H5-11A-62R-A115-07
# 1/2-SBSRNA4                      5.491853                      6.321928
# A1BG                             7.392317                      8.233620
# A1BG-AS1                         6.321928                      6.584963
# A1CF                             3.321928                      3.584963
# A2LD1                            7.643856                      8.276124
#
# [5 rows x 113 columns]
#              TCGA-A7-A425-01A-11R-A24H-07  TCGA-BH-A18G-01A-11R-A12D-07  \
# 1/2-SBSRNA4                      5.357552                      4.392317
# A1BG                             9.887221                      5.129283
# A1BG-AS1                         7.098032                      3.459432
# A1CF                             1.000000                      2.584963
# A2LD1                            7.451211                      7.189825
#
#              TCGA-BH-A0BD-01A-11R-A034-07  TCGA-B6-A0IB-01A-11R-A034-07  \
# 1/2-SBSRNA4                      5.754888                      5.954196
# A1BG                             8.209453                      9.911392
# A1BG-AS1                         6.906891                      7.076816
# A1CF                             2.000000                      2.321928
# A2LD1                            8.717676                      8.924813
#
#              TCGA-B6-A1KN-01A-11R-A13Q-07  TCGA-A2-A0YJ-01A-11R-A109-07  \
# 1/2-SBSRNA4                      6.022368                      3.906891
# A1BG                             7.794416                      6.857981
# A1BG-AS1                         6.643856                      5.584963
# A1CF                             4.000000                      0.000000
# A2LD1                            7.774787                      7.330917
#
#              TCGA-A2-A0YL-01A-21R-A109-07  TCGA-A2-A0YI-01A-31R-A10J-07  \
# 1/2-SBSRNA4                      5.882643                      5.614710
# A1BG                             8.499846                      8.954196
# A1BG-AS1                         6.108524                      6.906891
# A1CF                             1.000000                      2.584963
# A2LD1                            7.321928                      8.396605
#
#              TCGA-AR-A0U0-01A-11R-A109-07  TCGA-AR-A0TT-01A-31R-A084-07  ...  \
# 1/2-SBSRNA4                      5.247928                      4.087463  ...
# A1BG                             7.426265                      8.280771  ...
# A1BG-AS1                         5.977280                      6.894818  ...
# A1CF                             2.321928                      3.584963  ...
# A2LD1                            8.611025                      8.751544  ...
#
#              TCGA-AQ-A1H3-01A-31R-A13Q-07  TCGA-AO-A12B-01A-11R-A10J-07  \
# 1/2-SBSRNA4                      5.882643                      4.807355
# A1BG                             7.451211                      9.136991
# A1BG-AS1                         6.149747                      6.266787
# A1CF                             1.000000                      0.000000
# A2LD1                            8.622052                      6.741467
#
#              TCGA-AN-A0AL-01A-11R-A00Z-07  TCGA-D8-A1JJ-01A-31R-A14M-07  \
# 1/2-SBSRNA4                      5.000000                      4.857981
# A1BG                             7.033423                      8.471675
# A1BG-AS1                         4.906891                      6.741467
# A1CF                             3.169925                      2.584963
# A2LD1                            8.366322                      7.734710
#
#              TCGA-AC-A62Y-01A-11R-A29R-07  TCGA-AC-A6NO-01A-12R-A33J-07  \
# 1/2-SBSRNA4                      6.169925                      6.000000
# A1BG                             9.622052                      8.614710
# A1BG-AS1                         7.491853                      7.392317
# A1CF                             0.000000                      3.169925
# A2LD1                            7.294621                      7.832890
#
#              TCGA-C8-A8HP-01A-11R-A36F-07  TCGA-C8-A273-01A-11R-A16F-07  \
# 1/2-SBSRNA4                      4.807355                      6.044394
# A1BG                            10.188589                      9.317413
# A1BG-AS1                         7.022368                      7.276124
# A1CF                             0.000000                      2.584963
# A2LD1                            7.839204                      8.005625
#
#              TCGA-C8-A1HG-01A-11R-A137-07  TCGA-C8-A12U-01A-11R-A115-07
# 1/2-SBSRNA4                      5.000000                      4.754888
# A1BG                             8.252665                      9.278449
# A1BG-AS1                         5.459432                      6.169925
# A1CF                             0.000000                      0.000000
# A2LD1                            6.228819                      7.707359
#
# [5 rows x 1082 columns]

# %% [markdown]
# Dat ziet er uit dat het stabiliseren van de dataset met een log2-transformatie succesvol was. Nu het zoeken naar de DEG. Om deze te bepalen maken we gebruik van een meervoudige t-test en een log2 fold change. Wanneer het gen een p value kleiner dan `0.05f` en de log2 fold change groter dan `1.5f` bezit, nemen we het mee als een significante DEG.

# %%
deg_results_list = []

for gene in normal_data_subset.index:
    # Retrieving both gene values
    normal_values = normal_data_log.loc[gene].values
    cancer_values = cancer_data_log.loc[gene].values

    # Check if not 0
    if len(normal_values) == 0 or len(cancer_values) == 0:
        continue

    # T test
    t_stat, p_value = stats.ttest_ind(normal_values, cancer_values, nan_policy='omit')

    # Check valid p-value (no Nan)
    if np.isnan(p_value):
        continue

    # Calculate log2 fold change
    log2_fold_change = (cancer_values.mean() + 1e-9) / (normal_values.mean() + 1e-9)
    log2_fold_change = np.log2(log2_fold_change)

    deg_results_list.append({'gene': gene, 'p_value': p_value, 'log2_fold_change': log2_fold_change})

# Make dataframe
deg_results = pd.DataFrame(deg_results_list).set_index('gene')
print(f"Number of results: {len(deg_results)}")

# Correct multiple t-test with Benjamini-Hochberg method
deg_results['adjusted_p_value'] = multipletests(deg_results['p_value'], method='fdr_bh')[1]

significant_genes = deg_results[(deg_results['adjusted_p_value'] < 0.05) & (deg_results['log2_fold_change'].abs() > 1.5)]
print(f"Significant genes: {len(significant_genes)}")
print(significant_genes)
# Out:
# Number of results: 22828
# Significant genes: 397
#                     p_value  log2_fold_change  adjusted_p_value
# gene
# AADACL2        5.946168e-57         -2.053206      1.393625e-55
# AADACL3        5.175597e-47         -1.981595      8.751744e-46
# ACCN5          2.315207e-08          2.064753      6.013375e-08
# ACSM2A         1.131945e-77         -1.854185      5.617400e-76
# ACSM2B         2.678361e-69         -1.903352      9.814064e-68
# ...                     ...               ...               ...
# WBSCR28        1.204012e-52          1.992041      2.485099e-51
# WT1-AS         2.259882e-23          1.659053      1.407217e-22
# XAGE3          6.182491e-49         -2.147741      1.108672e-47
# ZNF670-ZNF695  9.198208e-13          2.282103      3.185809e-12
# ZP4            4.736589e-08          2.169195      1.203549e-07
#
# [397 rows x 3 columns]

# %% [markdown]
# Top, we hebben sigificante DEG voor borstkanker. Nu moeten we onderzoeken welke medicijnen hierbij gepaard gaan.

# %% [markdown]
# ## Matchen van Medicijnen
#
# Nu eenmaal in bezit van DEGs is de volgende taak, onderzoeken welke bekende medicijnen met deze genen betrokken zijn. Hiervoor zoeken we een dataset die medicijnen verbind aan genen. Een data zoals die van NIH LINCS program. De data staat op [https://maayanlab.cloud/sigcom-lincs/#/Download](https://maayanlab.cloud/sigcom-lincs/#/Download). Deze dataset heeft de vorm 4269x35239, ik ga er vanuit dat al onze deg zich hierin bevinden. Nu eerst de data inlezen.

# %%
drug_data = normal_data = pd.read_csv("data/human_geo_sigs.tsv", sep="\t", index_col=0)
print(drug_data.head())
# Out:
#                                                         A1BG      A1CF  \
# Identification of differentially expressed circ... -2.198815 -0.297826
# CRISPR Inversion of CTCF Sites Alters Genome To...  0.517292  0.000000
# mRNA differential expression in LNCaP cells exp...  0.208042  0.017953
# EHMT1 and EHMT2 inhibition induce fetal hemoglo...  0.167852  0.000000
# Prolyl hydroxylation regulates protein degradat...  0.340173 -0.002414
#
#                                                          A2M     A2ML1  \
# Identification of differentially expressed circ... -2.457639 -1.564745
# CRISPR Inversion of CTCF Sites Alters Genome To...  0.000000  0.000000
# mRNA differential expression in LNCaP cells exp...  1.650377 -0.820223
# EHMT1 and EHMT2 inhibition induce fetal hemoglo...  0.000000  0.018627
# Prolyl hydroxylation regulates protein degradat... -0.109122 -0.060994
#
#                                                        A2MP1  A3GALT2  \
# Identification of differentially expressed circ... -1.130169      0.0
# CRISPR Inversion of CTCF Sites Alters Genome To...  0.000000      0.0
# mRNA differential expression in LNCaP cells exp... -0.954188      0.0
# EHMT1 and EHMT2 inhibition induce fetal hemoglo...  0.000000      0.0
# Prolyl hydroxylation regulates protein degradat...  0.000000      0.0
#
#                                                       A4GALT  A4GNT      AAAS  \
# Identification of differentially expressed circ...  0.220567    0.0  0.082033
# CRISPR Inversion of CTCF Sites Alters Genome To...  0.000000    0.0  0.232037
# mRNA differential expression in LNCaP cells exp...  0.001050    0.0 -0.046449
# EHMT1 and EHMT2 inhibition induce fetal hemoglo... -0.191049    0.0 -0.230696
# Prolyl hydroxylation regulates protein degradat... -0.433200    0.0 -0.424783
#
#                                                         AACS  ...  \
# Identification of differentially expressed circ...  0.026167  ...
# CRISPR Inversion of CTCF Sites Alters Genome To...  0.102315  ...
# mRNA differential expression in LNCaP cells exp... -0.026154  ...
# EHMT1 and EHMT2 inhibition induce fetal hemoglo... -0.549092  ...
# Prolyl hydroxylation regulates protein degradat... -0.080122  ...
#
#                                                     bP-21201H5.1  \
# Identification of differentially expressed circ...      0.466660
# CRISPR Inversion of CTCF Sites Alters Genome To...     -0.206549
# mRNA differential expression in LNCaP cells exp...      0.000000
# EHMT1 and EHMT2 inhibition induce fetal hemoglo...      0.022583
# Prolyl hydroxylation regulates protein degradat...     -0.097979
#
#                                                     bP-21264C1.1  bP-2168N6.1  \
# Identification of differentially expressed circ...      0.000000          0.0
# CRISPR Inversion of CTCF Sites Alters Genome To...      0.189964          0.0
# mRNA differential expression in LNCaP cells exp...      0.149009          0.0
# EHMT1 and EHMT2 inhibition induce fetal hemoglo...      0.000000          0.0
# Prolyl hydroxylation regulates protein degradat...     -0.216017          0.0
#
#                                                     bP-2168N6.3  bP-2171C21.2  \
# Identification of differentially expressed circ...          0.0      0.000000
# CRISPR Inversion of CTCF Sites Alters Genome To...          0.0      0.000000
# mRNA differential expression in LNCaP cells exp...          0.0      3.014766
# EHMT1 and EHMT2 inhibition induce fetal hemoglo...          0.0      0.000000
# Prolyl hydroxylation regulates protein degradat...          0.0      0.000000
#
#                                                     bP-2171C21.4  \
# Identification of differentially expressed circ...      0.000000
# CRISPR Inversion of CTCF Sites Alters Genome To...      0.000000
# mRNA differential expression in LNCaP cells exp...     -0.600897
# EHMT1 and EHMT2 inhibition induce fetal hemoglo...      0.000000
# Prolyl hydroxylation regulates protein degradat...      0.000000
#
#                                                     bP-2171C21.5  \
# Identification of differentially expressed circ...      0.155162
# CRISPR Inversion of CTCF Sites Alters Genome To...      0.000000
# mRNA differential expression in LNCaP cells exp...      0.000000
# EHMT1 and EHMT2 inhibition induce fetal hemoglo...      0.000000
# Prolyl hydroxylation regulates protein degradat...      0.000000
#
#                                                     bP-2171C21.6  bP-2189O9.2  \
# Identification of differentially expressed circ...      0.000000    -2.198458
# CRISPR Inversion of CTCF Sites Alters Genome To...      0.000000    -0.392230
# mRNA differential expression in LNCaP cells exp...     -0.080791     0.671473
# EHMT1 and EHMT2 inhibition induce fetal hemoglo...      0.000000     0.000000
# Prolyl hydroxylation regulates protein degradat...      0.000000    -0.227477
#
#                                                     yR211F11.2
# Identification of differentially expressed circ...         0.0
# CRISPR Inversion of CTCF Sites Alters Genome To...         0.0
# mRNA differential expression in LNCaP cells exp...         0.0
# EHMT1 and EHMT2 inhibition induce fetal hemoglo...         0.0
# Prolyl hydroxylation regulates protein degradat...         0.0
#
# [5 rows x 35238 columns]

# %% [markdown]
# Dit ziet er veel belovend uit. De shape komt op 1 na overeen met wat de beschrijving is. Nu bekijken of al onze genen ook aanwezig zijn. in onze dataset.

# %%
# Check missing genes
significant_genes_common = significant_genes.index[significant_genes.index.isin(drug_data.columns)]
print(f"Aantal gemeenschappelijke genen: {len(significant_genes_common)}")
print(significant_genes_common)
# Out:
# Aantal gemeenschappelijke genen: 244
# Index(['AADACL2', 'AADACL3', 'ACSM2A', 'ACSM2B', 'ACTL8', 'ACTR3BP2', 'ADAM18',
#        'ADAMTS20', 'ADH7', 'ANGPTL7',
#        ...
#        'TLX1', 'TMEFF2', 'TPPP2', 'TUBA3C', 'UGT1A7', 'UGT2A1', 'WBSCR28',
#        'XAGE3', 'ZNF670-ZNF695', 'ZP4'],
#       dtype='object', name='gene', length=244)

# %% [markdown]
# Helaas missen er een aantal genen, maar gelukkig zijn er veel wel aanwezig. We gaan met de aanwezige genen verder! Dus gaan we een subset maken en hier mee verder.

# %%
drug_data_subset_common = drug_data[significant_genes_common]
# Controleer de afmetingen
print(f"Drug data subset shape: {drug_data_subset_common.shape}")
print(f"Significant genes subset shape: {significant_genes_common.shape}")
# Out:
# Drug data subset shape: (4269, 244)
# Significant genes subset shape: (244,)

# %% [markdown]
# Dat is goed gegaan. Nu we de data concreet hebben gaan we een correlatie analyze uitoefenen. Dit doen we om te onderzoeken welke medicijnen het sterkst met deze genen gecorreleerd worden.

# %%
# Bekijk de indexen van beide datasets voor zekerheid
print(significant_genes_common)
print(drug_data_subset_common.index)
"""
# Maak de lege DataFrame om de correlatie op te slaan
correlation_matrix = pd.DataFrame(index=drug_data_subset_common.index, columns=significant_genes_common)

# Bereken de Pearson correlatie tussen elk medicijn en de significante genen
for sample in drug_data_subset_common.index:  # Itereer door de samples in de drug data
    for gene in significant_genes_common.index:  # Itereer door de significante genen
        # Verkrijg de data voor dit sample en gen
        drug_values = drug_data_subset_common.loc[sample].values  # Waarden voor het medicijn
        gene_values = significant_genes_common.loc[gene].values  # Waarden voor het gen

        # Bereken de Pearson correlatie tussen het medicijn en het gen
        corr, _ = stats.pearsonr(drug_values, gene_values)

        # Sla de correlatie op in de matrix
        correlation_matrix.loc[sample, gene] = corr

# Bekijk de correlatiematrix
print(correlation_matrix.head())
"""
# Out:
# Index(['AADACL2', 'AADACL3', 'ACSM2A', 'ACSM2B', 'ACTL8', 'ACTR3BP2', 'ADAM18',
#        'ADAMTS20', 'ADH7', 'ANGPTL7',
#        ...
#        'TLX1', 'TMEFF2', 'TPPP2', 'TUBA3C', 'UGT1A7', 'UGT2A1', 'WBSCR28',
#        'XAGE3', 'ZNF670-ZNF695', 'ZP4'],
#       dtype='object', name='gene', length=244)
# Index(['Identification of differentially expressed circRNA in gallbladder cancer compared with matched normal tissue GSE100363_1',
#        'CRISPR Inversion of CTCF Sites Alters Genome Topology and Enhancer/Promoter Function GSE71275_1',
#        'mRNA differential expression in LNCaP cells expressing the wild-type androgen receptor (AR-WT) or the ligand-independent AR-V7 splice variant GSE71334_1',
#        'EHMT1 and EHMT2 inhibition induce fetal hemoglobin expression [RNA-seq] GSE71421_1',
#        'Prolyl hydroxylation regulates protein degradation, synthesis, and splicing in human induced pluripotent stem cell-derived cardiomyocytes GSE71560_1',
#        'FUS KO mRNA sequencing and anti-FUS RNA immunoprecipitation sequencing GSE71812_1',
#        'GATA3-mediated chromatin reprogramming in breast cancer cells GSE72141_1',
#        'The Ro60 Autoantigen Binds Endogenous Retroelements and Regulates Inflammatory Gene Expression GSE72420_1',
#        'Transcriptome profiles of moderate dysplasia in oral mucosa associated with malignant conversion GSE72627_1',
#        'Promoter H3K4 methylation reveals the dynamic reinforcement of activation-induced pathways in human CD4 T cells with differential kinetics in naïve and memory cells (RNA-Seq) GSE73213_1',
#        ...
#        'Proteasome machinery is instrumental in a common gain-of-function program of the p53 missense mutants in cancer. GSE68248_1',
#        '3D Chromosome Regulatory Landscape of Human Pluripotent Cells GSE69647_1',
#        'RNA sequencing of mechanically strained NHEKs and control NHEKs GSE70084_1',
#        'Rocaglamide A converts RNA helicase eIF4A into a sequence-specific translational repressor GSE70211_1',
#        'Investigation about Monocytes in metastatic breast cancer patients under chemotherapy +/- Avastin GSE70404_1',
#        'A network-based strategy for prioritizing hits from chemical screening data by leveraging genetic, epigenetic and transcriptional datasets GSE70810_1',
#        'Treatment of prostate cancer cells with S-adenosylmethionine leads to genomewide alterations of transcription profiles GSE71070_1',
#        'Next Generation Sequencing Facilitates Quantitative Analysis of PBX3 Regulated Transcriptomes GSE71261_1',
#        'RNAseq analysis of ESRP regulated splicing events in prostate cancer GSE129540_1',
#        'Differential expression of pancreatic cancer  PANC1 cells treated with pilocarpine GSE102880_1'],
#       dtype='object', length=4269)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 10
#       8 # Bereken de Pearson correlatie tussen elk medicijn en de significante genen
#       9 for sample in drug_data_subset_common.index:  # Itereer door de samples in de drug data
# ---> 10     for gene in significant_genes_common.index:  # Itereer door de significante genen
#      11         # Verkrijg de data voor dit sample en gen
#      12         drug_values = drug_data_subset_common.loc[sample].values  # Waarden voor het medicijn
#      13         gene_values = significant_genes_common.loc[gene].values  # Waarden voor het gen
#
# AttributeError: 'Index' object has no attribute 'index'

# %% [markdown]
# > --Helaas is mijn code gebroken, verder is de uitkomst toch niet wat we zoeken, vandaar reflectie hieronder van toen het nog werkte--
#
# Dit resultaat duit op een misverstand. Mijn resultaat van wat ik verwachte wijkt af, ik heb namelijk relevante studies op basis van mijn deg. Niet relevante medicijnen. Dit komt door het niet goed onderzoeken van mijn data en wat het precies bevat. Conclusie: Het verbinden van expressiedata en data afkomstig van relevante studies is mogelijk, dus dan zal het ook mogelijk moeten zijn om dit met medicijn-data te doen. Op zichzelf toont dit aan dat het gebruiken van expressie data vele kanten en mogelijkheden biedt, en ook invalshoeken die je soms niet verwacht of al onderzocht zijn.
#
# Voor nu weer een stap terug, het zoeken van Medicijn data.
#
# Er is een handmatig geannoteerde dataset die genen aan medicijnen verbindt. Deze bevat 875 verschillende middelen met elk relevante genen. Met mijn lijst van DEGs kan ik het hiermee in een netwerk leggen. De data is afkomstig uit [https://maayanlab.cloud/CREEDS/](https://maayanlab.cloud/CREEDS/), de v1.0	Manual single drug perturbations. Eerst kijken of het echt over middelen gaat, aangezien dit eerder wel beter gecontroleerd kon worden. De achtergrond staat het volgende artikel:
#  > Wang, Z., Monteiro, C., Jagodnik, K. et al. Extraction and analysis of signatures from the Gene Expression Omnibus by the crowd. Nat Commun 7, 12846 (2016). https://doi.org/10.1038/ncomms12846.

# %%
drug_file = "data/single_drug_perturbations-v1.0.gmt"

with open(drug_file, 'r') as file:
    drug_file = {}
    for line in file:
        parts = line.strip().split('\t')
        drug_file[parts[0]] = parts[2:]

# print all compounds
for gene_set, genes in drug_file.items():
    print(f"Genenset: {gene_set}, Aantal genen: {len(genes)}")
# Out:
# Genenset: Fluorouracil-up, Aantal genen: 314
# Genenset: Fluorouracil-dn, Aantal genen: 283
# Genenset: Resveratrol-up, Aantal genen: 359
# Genenset: Resveratrol-dn, Aantal genen: 241
# Genenset: Citalopram-up, Aantal genen: 341
# Genenset: Citalopram-dn, Aantal genen: 250
# Genenset: Ethanol-up, Aantal genen: 331
# Genenset: Ethanol-dn, Aantal genen: 240
# Genenset: Sodium arsenite-up, Aantal genen: 309
# Genenset: Sodium arsenite-dn, Aantal genen: 284
# Genenset: Vitamin c-up, Aantal genen: 250
# Genenset: Vitamin c-dn, Aantal genen: 322
# Genenset: Perfluorooctanoic acid-up, Aantal genen: 218
# Genenset: Perfluorooctanoic acid-dn, Aantal genen: 373
# Genenset: Formaldehyde-up, Aantal genen: 271
# Genenset: Formaldehyde-dn, Aantal genen: 329
# Genenset: Tretinoin-up, Aantal genen: 359
# Genenset: Tretinoin-dn, Aantal genen: 241
# Genenset: Vitamin e-up, Aantal genen: 258
# Genenset: Vitamin e-dn, Aantal genen: 340
# Genenset: Gefitinib-up, Aantal genen: 117
# Genenset: Gefitinib-dn, Aantal genen: 483
# Genenset: Methylprednisolone-up, Aantal genen: 319
# Genenset: Methylprednisolone-dn, Aantal genen: 272
# Genenset: Levetiracetam-up, Aantal genen: 140
# Genenset: Levetiracetam-dn, Aantal genen: 459
# Genenset: Rosiglitazone-up, Aantal genen: 373
# Genenset: Rosiglitazone-dn, Aantal genen: 226
# Genenset: Alitretinoin-up, Aantal genen: 289
# Genenset: Alitretinoin-dn, Aantal genen: 305
# Genenset: Pristane-up, Aantal genen: 312
# Genenset: Pristane-dn, Aantal genen: 280
# Genenset: Hypochlorous acid-up, Aantal genen: 257
# Genenset: Hypochlorous acid-dn, Aantal genen: 343
# Genenset: Methoxychlor-up, Aantal genen: 277
# Genenset: Methoxychlor-dn, Aantal genen: 319
# Genenset: 4-vinylcyclohexene diepoxide-up, Aantal genen: 241
# Genenset: 4-vinylcyclohexene diepoxide-dn, Aantal genen: 352
# Genenset: 4-hydroxytamoxifen-up, Aantal genen: 364
# Genenset: 4-hydroxytamoxifen-dn, Aantal genen: 231
# Genenset: Leptin-up, Aantal genen: 190
# Genenset: Leptin-dn, Aantal genen: 406
# Genenset: Morphine-up, Aantal genen: 164
# Genenset: Morphine-dn, Aantal genen: 432
# Genenset: Mycophenolic acid-up, Aantal genen: 307
# Genenset: Mycophenolic acid-dn, Aantal genen: 285
# Genenset: Acetaminophen-up, Aantal genen: 230
# Genenset: Acetaminophen-dn, Aantal genen: 364
# Genenset: Abiraterone-up, Aantal genen: 236
# Genenset: Abiraterone-dn, Aantal genen: 351
# Genenset: Trichloroethylene-up, Aantal genen: 160
# Genenset: Trichloroethylene-dn, Aantal genen: 440
# Genenset: Cisplatin-up, Aantal genen: 468
# Genenset: Cisplatin-dn, Aantal genen: 118
# Genenset: Metoprolol-up, Aantal genen: 240
# Genenset: Metoprolol-dn, Aantal genen: 358
# Genenset: Azacitidine-up, Aantal genen: 319
# Genenset: Azacitidine-dn, Aantal genen: 281
# Genenset: Methotrexate-up, Aantal genen: 314
# Genenset: Methotrexate-dn, Aantal genen: 280
# Genenset: Decitabine-up, Aantal genen: 279
# Genenset: Decitabine-dn, Aantal genen: 320
# Genenset: Imatinib-up, Aantal genen: 237
# Genenset: Imatinib-dn, Aantal genen: 340
# Genenset: Doxorubicin-up, Aantal genen: 303
# Genenset: Doxorubicin-dn, Aantal genen: 292
# Genenset: Apratoxin a-up, Aantal genen: 170
# Genenset: Apratoxin a-dn, Aantal genen: 429
# Genenset: Estradiol-up, Aantal genen: 332
# Genenset: Estradiol-dn, Aantal genen: 267
# Genenset: Hydroxyzine-up, Aantal genen: 220
# Genenset: Hydroxyzine-dn, Aantal genen: 373
# Genenset: Ribavirin-up, Aantal genen: 221
# Genenset: Ribavirin-dn, Aantal genen: 378
# Genenset: Cycloheximide-up, Aantal genen: 342
# Genenset: Cycloheximide-dn, Aantal genen: 252
# Genenset: Bleomycin-up, Aantal genen: 262
# Genenset: Bleomycin-dn, Aantal genen: 312
# Genenset: Diclofenac-up, Aantal genen: 260
# Genenset: Diclofenac-dn, Aantal genen: 339
# Genenset: Etanercept-up, Aantal genen: 338
# Genenset: Etanercept-dn, Aantal genen: 258
# Genenset: Chromium(iii) nicotinate-up, Aantal genen: 256
# Genenset: Chromium(iii) nicotinate-dn, Aantal genen: 338
# Genenset: Lipopolysaccharide-up, Aantal genen: 371
# Genenset: Lipopolysaccharide-dn, Aantal genen: 227
# Genenset: Sorafenib-up, Aantal genen: 275
# Genenset: Sorafenib-dn, Aantal genen: 325
# Genenset: Coenzyme q10-up, Aantal genen: 260
# Genenset: Coenzyme q10-dn, Aantal genen: 334
# Genenset: 2,3-dimethoxy-1,4-naphtoquinone (dmnq)-up, Aantal genen: 309
# Genenset: 2,3-dimethoxy-1,4-naphtoquinone (dmnq)-dn, Aantal genen: 288
# Genenset: Argyrin a-up, Aantal genen: 353
# Genenset: Argyrin a-dn, Aantal genen: 243
# Genenset: Lapatinib-up, Aantal genen: 302
# Genenset: Lapatinib-dn, Aantal genen: 298
# Genenset: Nicotinamide riboside-up, Aantal genen: 261
# Genenset: Nicotinamide riboside-dn, Aantal genen: 339
# Genenset: Curcumin-up, Aantal genen: 38
# Genenset: Curcumin-dn, Aantal genen: 562
# Genenset: Progesterone-up, Aantal genen: 200
# Genenset: Progesterone-dn, Aantal genen: 398
# Genenset: Cetuximab-up, Aantal genen: 302
# Genenset: Cetuximab-dn, Aantal genen: 298
# Genenset: Genistein-up, Aantal genen: 228
# Genenset: Genistein-dn, Aantal genen: 366
# Genenset: Bisphenol a-up, Aantal genen: 172
# Genenset: Bisphenol a-dn, Aantal genen: 424
# Genenset: Lysophosphatidic acid-up, Aantal genen: 297
# Genenset: Lysophosphatidic acid-dn, Aantal genen: 302
# Genenset: Adenosine triphosphate-up, Aantal genen: 239
# Genenset: Adenosine triphosphate-dn, Aantal genen: 354
# Genenset: Lmp-420-up, Aantal genen: 382
# Genenset: Lmp-420-dn, Aantal genen: 214
# Genenset: Harman-up, Aantal genen: 306
# Genenset: Harman-dn, Aantal genen: 287
# Genenset: Torcetrapib-up, Aantal genen: 384
# Genenset: Torcetrapib-dn, Aantal genen: 211
# Genenset: Nickel-up, Aantal genen: 324
# Genenset: Nickel-dn, Aantal genen: 269
# Genenset: Rituximab-up, Aantal genen: 198
# Genenset: Rituximab-dn, Aantal genen: 393
# Genenset: Paclitaxel-up, Aantal genen: 227
# Genenset: Paclitaxel-dn, Aantal genen: 371
# Genenset: Aminolevulinic acid-up, Aantal genen: 279
# Genenset: Aminolevulinic acid-dn, Aantal genen: 321
# Genenset: Pimecrolimus-up, Aantal genen: 336
# Genenset: Pimecrolimus-dn, Aantal genen: 258
# Genenset: Doxycycline-up, Aantal genen: 404
# Genenset: Doxycycline-dn, Aantal genen: 191
# Genenset: Deferasirox-up, Aantal genen: 256
# Genenset: Deferasirox-dn, Aantal genen: 340
# Genenset: Plx4032-up, Aantal genen: 249
# Genenset: Plx4032-dn, Aantal genen: 339
# Genenset: Vanadium pentoxide-up, Aantal genen: 357
# Genenset: Vanadium pentoxide-dn, Aantal genen: 242
# Genenset: Calcitriol-up, Aantal genen: 356
# Genenset: Calcitriol-dn, Aantal genen: 243
# Genenset: Palmitic acid-up, Aantal genen: 294
# Genenset: Palmitic acid-dn, Aantal genen: 303
# Genenset: Pd173074-up, Aantal genen: 269
# Genenset: Pd173074-dn, Aantal genen: 316
# Genenset: Isotretinoin-up, Aantal genen: 157
# Genenset: Isotretinoin-dn, Aantal genen: 443
# Genenset: Captopril-up, Aantal genen: 317
# Genenset: Captopril-dn, Aantal genen: 275
# Genenset: Methylphenidate-up, Aantal genen: 198
# Genenset: Methylphenidate-dn, Aantal genen: 395
# Genenset: Caerulein-up, Aantal genen: 267
# Genenset: Caerulein-dn, Aantal genen: 330
# Genenset: Sodium butyrate-up, Aantal genen: 289
# Genenset: Sodium butyrate-dn, Aantal genen: 309
# Genenset: Bexarotene-up, Aantal genen: 333
# Genenset: Bexarotene-dn, Aantal genen: 267
# Genenset: Alfacalcidol-up, Aantal genen: 336
# Genenset: Alfacalcidol-dn, Aantal genen: 262
# Genenset: Plx4720-up, Aantal genen: 290
# Genenset: Plx4720-dn, Aantal genen: 310
# Genenset: 2,3,7,8-tetrachlorodibenzo-p-dioxin-up, Aantal genen: 241
# Genenset: 2,3,7,8-tetrachlorodibenzo-p-dioxin-dn, Aantal genen: 356
# Genenset: Atorvastatin-up, Aantal genen: 283
# Genenset: Atorvastatin-dn, Aantal genen: 312
# Genenset: Soman-up, Aantal genen: 340
# Genenset: Soman-dn, Aantal genen: 259
# Genenset: Phosgene-up, Aantal genen: 301
# Genenset: Phosgene-dn, Aantal genen: 293
# Genenset: Insulin-up, Aantal genen: 259
# Genenset: Insulin-dn, Aantal genen: 337
# Genenset: Concanavalin a-up, Aantal genen: 198
# Genenset: Concanavalin a-dn, Aantal genen: 392
# Genenset: Vemurafenib-up, Aantal genen: 320
# Genenset: Vemurafenib-dn, Aantal genen: 280
# Genenset: Fenretinide-up, Aantal genen: 175
# Genenset: Fenretinide-dn, Aantal genen: 420
# Genenset: Sodium pyruvate-up, Aantal genen: 433
# Genenset: Sodium pyruvate-dn, Aantal genen: 163
# Genenset: N-nitrosodimethylamine-up, Aantal genen: 278
# Genenset: N-nitrosodimethylamine-dn, Aantal genen: 322
# Genenset: 1-naphthyl isothiocyanate-up, Aantal genen: 280
# Genenset: 1-naphthyl isothiocyanate-dn, Aantal genen: 317
# Genenset: Glipizide-up, Aantal genen: 337
# Genenset: Glipizide-dn, Aantal genen: 258
# Genenset: Cyclophosphamide-up, Aantal genen: 362
# Genenset: Cyclophosphamide-dn, Aantal genen: 236
# Genenset: Cadmium-up, Aantal genen: 258
# Genenset: Cadmium-dn, Aantal genen: 324
# Genenset: Epz004777-up, Aantal genen: 231
# Genenset: Epz004777-dn, Aantal genen: 364
# Genenset: Folic acid-up, Aantal genen: 261
# Genenset: Folic acid-dn, Aantal genen: 339
# Genenset: Metformin-up, Aantal genen: 327
# Genenset: Metformin-dn, Aantal genen: 267
# Genenset: Irinotecan-up, Aantal genen: 260
# Genenset: Irinotecan-dn, Aantal genen: 340
# Genenset: Zinc acetate-up, Aantal genen: 185
# Genenset: Zinc acetate-dn, Aantal genen: 413
# Genenset: Mehp-up, Aantal genen: 265
# Genenset: Mehp-dn, Aantal genen: 335
# Genenset: Colchicine-up, Aantal genen: 340
# Genenset: Colchicine-dn, Aantal genen: 256
# Genenset: Chlorambucil-up, Aantal genen: 337
# Genenset: Chlorambucil-dn, Aantal genen: 258
# Genenset: Thapsigargin-up, Aantal genen: 275
# Genenset: Thapsigargin-dn, Aantal genen: 324
# Genenset: Bpde-up, Aantal genen: 363
# Genenset: Bpde-dn, Aantal genen: 236
# Genenset: Cytarabine-up, Aantal genen: 274
# Genenset: Cytarabine-dn, Aantal genen: 323
# Genenset: Dapt-up, Aantal genen: 326
# Genenset: Dapt-dn, Aantal genen: 273
# Genenset: Puromycin, 2xec50, 1d-up, Aantal genen: 247
# Genenset: Puromycin, 2xec50, 1d-dn, Aantal genen: 353
# Genenset: Cobalt dichloride hexahydrate-up, Aantal genen: 293
# Genenset: Cobalt dichloride hexahydrate-dn, Aantal genen: 305
# Genenset: Acrylamide-up, Aantal genen: 195
# Genenset: Acrylamide-dn, Aantal genen: 403
# Genenset: Olanzapine-up, Aantal genen: 201
# Genenset: Olanzapine-dn, Aantal genen: 398
# Genenset: N-methylformamide-up, Aantal genen: 294
# Genenset: N-methylformamide-dn, Aantal genen: 304
# Genenset: Chlorpyrifos-up, Aantal genen: 424
# Genenset: Chlorpyrifos-dn, Aantal genen: 171
# Genenset: Cyfluthrin-up, Aantal genen: 391
# Genenset: Cyfluthrin-dn, Aantal genen: 204
# Genenset: Ethinyl estradiol-up, Aantal genen: 246
# Genenset: Ethinyl estradiol-dn, Aantal genen: 354
# Genenset: Hydrogen peroxide-up, Aantal genen: 371
# Genenset: Hydrogen peroxide-dn, Aantal genen: 226
# Genenset: Dmnq   (2,3-dimethoxy-1,4-naphthoquinone)-up, Aantal genen: 314
# Genenset: Dmnq   (2,3-dimethoxy-1,4-naphthoquinone)-dn, Aantal genen: 286
# Genenset: Mln4924-up, Aantal genen: 413
# Genenset: Mln4924-dn, Aantal genen: 187
# Genenset: Cediranib-up, Aantal genen: 331
# Genenset: Cediranib-dn, Aantal genen: 268
# Genenset: Quercetin-up, Aantal genen: 131
# Genenset: Quercetin-dn, Aantal genen: 464
# Genenset: Dexamethasone-up, Aantal genen: 260
# Genenset: Dexamethasone-dn, Aantal genen: 338
# Genenset: Streptozocin-up, Aantal genen: 231
# Genenset: Streptozocin-dn, Aantal genen: 361
# Genenset: Medroxyprogesterone acetate-up, Aantal genen: 343
# Genenset: Medroxyprogesterone acetate-dn, Aantal genen: 248
# Genenset: Diethylstilbestrol-up, Aantal genen: 328
# Genenset: Diethylstilbestrol-dn, Aantal genen: 270
# Genenset: Ciprofloxacin-up, Aantal genen: 302
# Genenset: Ciprofloxacin-dn, Aantal genen: 298
# Genenset: Pioglitazone-up, Aantal genen: 282
# Genenset: Pioglitazone-dn, Aantal genen: 314
# Genenset: Dasatinib-up, Aantal genen: 307
# Genenset: Dasatinib-dn, Aantal genen: 293
# Genenset: Cholestyramine-up, Aantal genen: 464
# Genenset: Cholestyramine-dn, Aantal genen: 135
# Genenset: Oprelvekin-up, Aantal genen: 362
# Genenset: Oprelvekin-dn, Aantal genen: 229
# Genenset: Celecoxib-up, Aantal genen: 316
# Genenset: Celecoxib-dn, Aantal genen: 283
# Genenset: Phenytoin-up, Aantal genen: 175
# Genenset: Phenytoin-dn, Aantal genen: 424
# Genenset: Insulin regular-up, Aantal genen: 370
# Genenset: Insulin regular-dn, Aantal genen: 214
# Genenset: Carbidopa-up, Aantal genen: 316
# Genenset: Carbidopa-dn, Aantal genen: 264
# Genenset: Cyclosporine-up, Aantal genen: 296
# Genenset: Cyclosporine-dn, Aantal genen: 296
# Genenset: Interferon beta-1b-up, Aantal genen: 251
# Genenset: Interferon beta-1b-dn, Aantal genen: 344
# Genenset: Vx-up, Aantal genen: 381
# Genenset: Vx-dn, Aantal genen: 218
# Genenset: 2,2',4,4',5,5'-hexachlorobiphenyl   (pcb-153)-up, Aantal genen: 275
# Genenset: 2,2',4,4',5,5'-hexachlorobiphenyl   (pcb-153)-dn, Aantal genen: 323
# Genenset: Simvastatin-up, Aantal genen: 209
# Genenset: Simvastatin-dn, Aantal genen: 385
# Genenset: Sangivamycin (nsc 65346)-up, Aantal genen: 446
# Genenset: Sangivamycin (nsc 65346)-dn, Aantal genen: 151
# Genenset: Mepenzolate bromide-up, Aantal genen: 330
# Genenset: Mepenzolate bromide-dn, Aantal genen: 264
# Genenset: Arc (nsc 188491)-up, Aantal genen: 410
# Genenset: Arc (nsc 188491)-dn, Aantal genen: 185
# Genenset: Fluoxetine-up, Aantal genen: 313
# Genenset: Fluoxetine-dn, Aantal genen: 283
# Genenset: Lubiprostone-up, Aantal genen: 367
# Genenset: Lubiprostone-dn, Aantal genen: 224
# Genenset: Trastuzumab-up, Aantal genen: 324
# Genenset: Trastuzumab-dn, Aantal genen: 276
# Genenset: Motexafin gadolinium (4 h)-up, Aantal genen: 238
# Genenset: Motexafin gadolinium (4 h)-dn, Aantal genen: 361
# Genenset: Pertuzumab-up, Aantal genen: 329
# Genenset: Pertuzumab-dn, Aantal genen: 271
# Genenset: Orotic acid-up, Aantal genen: 107
# Genenset: Orotic acid-dn, Aantal genen: 488
# Genenset: Cadmium dichloride-up, Aantal genen: 288
# Genenset: Cadmium dichloride-dn, Aantal genen: 311
# Genenset: Tamoxifen-up, Aantal genen: 354
# Genenset: Tamoxifen-dn, Aantal genen: 227
# Genenset: Sodium dichromate-up, Aantal genen: 341
# Genenset: Sodium dichromate-dn, Aantal genen: 258
# Genenset: Nickel chloride-up, Aantal genen: 286
# Genenset: Nickel chloride-dn, Aantal genen: 312
# Genenset: Mesalazine-up, Aantal genen: 198
# Genenset: Mesalazine-dn, Aantal genen: 394
# Genenset: Mepenzolate-up, Aantal genen: 266
# Genenset: Mepenzolate-dn, Aantal genen: 317
# Genenset: Ubiquinol-up, Aantal genen: 268
# Genenset: Ubiquinol-dn, Aantal genen: 326
# Genenset: Casiigly-up, Aantal genen: 453
# Genenset: Casiigly-dn, Aantal genen: 146
# Genenset: Heroin-up, Aantal genen: 272
# Genenset: Heroin-dn, Aantal genen: 328
# Genenset: Arsenic-up, Aantal genen: 509
# Genenset: Arsenic-dn, Aantal genen: 82
# Genenset: Phenol-up, Aantal genen: 226
# Genenset: Phenol-dn, Aantal genen: 374
# Genenset: D-serine-up, Aantal genen: 200
# Genenset: D-serine-dn, Aantal genen: 400
# Genenset: Pyrazinamide-up, Aantal genen: 539
# Genenset: Pyrazinamide-dn, Aantal genen: 38
# Genenset: Valproic acid-up, Aantal genen: 329
# Genenset: Valproic acid-dn, Aantal genen: 267
# Genenset: Nilotinib-up, Aantal genen: 201
# Genenset: Nilotinib-dn, Aantal genen: 394
# Genenset: Aldosterone-up, Aantal genen: 275
# Genenset: Aldosterone-dn, Aantal genen: 324
# Genenset: Amoxicillin-up, Aantal genen: 324
# Genenset: Amoxicillin-dn, Aantal genen: 273
# Genenset: Dactinomycin-up, Aantal genen: 283
# Genenset: Dactinomycin-dn, Aantal genen: 315
# Genenset: Natural alpha interferon-up, Aantal genen: 300
# Genenset: Natural alpha interferon-dn, Aantal genen: 299
# Genenset: Menadione-up, Aantal genen: 445
# Genenset: Menadione-dn, Aantal genen: 148
# Genenset: Ascorbic acid-up, Aantal genen: 457
# Genenset: Ascorbic acid-dn, Aantal genen: 139
# Genenset: Pbde 47-up, Aantal genen: 305
# Genenset: Pbde 47-dn, Aantal genen: 295
# Genenset: Vancomycin-up, Aantal genen: 282
# Genenset: Vancomycin-dn, Aantal genen: 318
# Genenset: Clozapine-up, Aantal genen: 319
# Genenset: Clozapine-dn, Aantal genen: 278
# Genenset: Monuron-up, Aantal genen: 315
# Genenset: Monuron-dn, Aantal genen: 284
# Genenset: Haloperidol-up, Aantal genen: 377
# Genenset: Haloperidol-dn, Aantal genen: 221
# Genenset: Phenobarbital sodium-up, Aantal genen: 436
# Genenset: Phenobarbital sodium-dn, Aantal genen: 163
# Genenset: Azathioprine-up, Aantal genen: 317
# Genenset: Azathioprine-dn, Aantal genen: 277
# Genenset: Isoflurane-up, Aantal genen: 298
# Genenset: Isoflurane-dn, Aantal genen: 302
# Genenset: Propofol-up, Aantal genen: 228
# Genenset: Propofol-dn, Aantal genen: 369
# Genenset: Puromycin, 2xec50, 3 d-up, Aantal genen: 263
# Genenset: Puromycin, 2xec50, 3 d-dn, Aantal genen: 336
# Genenset: Fasudil-up, Aantal genen: 242
# Genenset: Fasudil-dn, Aantal genen: 358
# Genenset: Sevoflurane-up, Aantal genen: 267
# Genenset: Sevoflurane-dn, Aantal genen: 330
# Genenset: Permethrin-up, Aantal genen: 368
# Genenset: Permethrin-dn, Aantal genen: 231
# Genenset: Arachidonic acid-up, Aantal genen: 567
# Genenset: Arachidonic acid-dn, Aantal genen: 31
# Genenset: Cadmium chloride-up, Aantal genen: 562
# Genenset: Cadmium chloride-dn, Aantal genen: 37
# Genenset: Androstanolone-up, Aantal genen: 214
# Genenset: Androstanolone-dn, Aantal genen: 381
# Genenset: Imatinib (glivec)-up, Aantal genen: 321
# Genenset: Imatinib (glivec)-dn, Aantal genen: 276
# Genenset: Fluticasone-up, Aantal genen: 444
# Genenset: Fluticasone-dn, Aantal genen: 154
# Genenset: Letrozole-up, Aantal genen: 298
# Genenset: Letrozole-dn, Aantal genen: 297
# Genenset: Corticosterone-up, Aantal genen: 355
# Genenset: Corticosterone-dn, Aantal genen: 239
# Genenset: Rosiglitazone effect on prdm16-deficient inguinal white adipose tissue-up, Aantal genen: 382
# Genenset: Rosiglitazone effect on prdm16-deficient inguinal white adipose tissue-dn, Aantal genen: 211
# Genenset: Actinomycin d-up, Aantal genen: 332
# Genenset: Actinomycin d-dn, Aantal genen: 267
# Genenset: Mek inhibitor (meki : azd6244)-up, Aantal genen: 373
# Genenset: Mek inhibitor (meki : azd6244)-dn, Aantal genen: 223
# Genenset: Deltamethrin-up, Aantal genen: 439
# Genenset: Deltamethrin-dn, Aantal genen: 160
# Genenset: Cigarette smoke-up, Aantal genen: 233
# Genenset: Cigarette smoke-dn, Aantal genen: 364
# Genenset: Nsc319726-up, Aantal genen: 231
# Genenset: Nsc319726-dn, Aantal genen: 367
# Genenset: Interferon gamma-1b-up, Aantal genen: 258
# Genenset: Interferon gamma-1b-dn, Aantal genen: 342
# Genenset: Angiotensin ii-up, Aantal genen: 119
# Genenset: Angiotensin ii-dn, Aantal genen: 475
# Genenset: Luteolin-up, Aantal genen: 212
# Genenset: Luteolin-dn, Aantal genen: 388
# Genenset: Interferon beta-1a-up, Aantal genen: 321
# Genenset: Interferon beta-1a-dn, Aantal genen: 276
# Genenset: Mercury-up, Aantal genen: 342
# Genenset: Mercury-dn, Aantal genen: 258
# Genenset: Nitric oxide-up, Aantal genen: 328
# Genenset: Nitric oxide-dn, Aantal genen: 268
# Genenset: 3h-1,2-dithiole-3-thione-up, Aantal genen: 262
# Genenset: 3h-1,2-dithiole-3-thione-dn, Aantal genen: 330
# Genenset: Motexafin gadolinium-up, Aantal genen: 279
# Genenset: Motexafin gadolinium-dn, Aantal genen: 319
# Genenset: 2,3,7,8-tetrachlorodibenzo-p-dioxin (tcdd)-up, Aantal genen: 299
# Genenset: 2,3,7,8-tetrachlorodibenzo-p-dioxin (tcdd)-dn, Aantal genen: 300
# Genenset: Halothane-up, Aantal genen: 326
# Genenset: Halothane-dn, Aantal genen: 269
# Genenset: Trichostatin a-up, Aantal genen: 582
# Genenset: Trichostatin a-dn, Aantal genen: 13
# Genenset: Anastrozole-up, Aantal genen: 184
# Genenset: Anastrozole-dn, Aantal genen: 411
# Genenset: 4-hydroxynonenal-up, Aantal genen: 381
# Genenset: 4-hydroxynonenal-dn, Aantal genen: 217
# Genenset: Bicalutamide-up, Aantal genen: 529
# Genenset: Bicalutamide-dn, Aantal genen: 65
# Genenset: Carboplatin-up, Aantal genen: 252
# Genenset: Carboplatin-dn, Aantal genen: 348
# Genenset: Gamma-tocotrienol-up, Aantal genen: 275
# Genenset: Gamma-tocotrienol-dn, Aantal genen: 325
# Genenset: Phorbol 12-myristate 13-acetate (pma)-up, Aantal genen: 269
# Genenset: Phorbol 12-myristate 13-acetate (pma)-dn, Aantal genen: 324
# Genenset: Nvp-tnks656 (tankyrase inhibitor)-up, Aantal genen: 455
# Genenset: Nvp-tnks656 (tankyrase inhibitor)-dn, Aantal genen: 141
# Genenset: Fgfr-specific pd173074 inhibitor-up, Aantal genen: 204
# Genenset: Fgfr-specific pd173074 inhibitor-dn, Aantal genen: 387
# Genenset: Nvp-tnks656-up, Aantal genen: 449
# Genenset: Nvp-tnks656-dn, Aantal genen: 150
# Genenset: Aplidin-up, Aantal genen: 351
# Genenset: Aplidin-dn, Aantal genen: 247
# Genenset: Nicotine-up, Aantal genen: 424
# Genenset: Nicotine-dn, Aantal genen: 175
# Genenset: Vitamin a-up, Aantal genen: 353
# Genenset: Vitamin a-dn, Aantal genen: 243
# Genenset: Trovafloxacin-up, Aantal genen: 441
# Genenset: Trovafloxacin-dn, Aantal genen: 157
# Genenset: Levofloxacin-up, Aantal genen: 269
# Genenset: Levofloxacin-dn, Aantal genen: 330
# Genenset: Methamphetamine-up, Aantal genen: 256
# Genenset: Methamphetamine-dn, Aantal genen: 344
# Genenset: Grepafloxacin-up, Aantal genen: 460
# Genenset: Grepafloxacin-dn, Aantal genen: 139
# Genenset: Gatifloxacin-up, Aantal genen: 234
# Genenset: Gatifloxacin-dn, Aantal genen: 363
# Genenset: Clinafloxacin-up, Aantal genen: 397
# Genenset: Clinafloxacin-dn, Aantal genen: 202
# Genenset: Colistin-up, Aantal genen: 309
# Genenset: Colistin-dn, Aantal genen: 291
# Genenset: Bortezomib-up, Aantal genen: 290
# Genenset: Bortezomib-dn, Aantal genen: 310
# Genenset: Phorbol ester 12-o-tetradecanoylphorbol-13-acetate (tpa)-up, Aantal genen: 163
# Genenset: Phorbol ester 12-o-tetradecanoylphorbol-13-acetate (tpa)-dn, Aantal genen: 406
# Genenset: Cocaine-up, Aantal genen: 285
# Genenset: Cocaine-dn, Aantal genen: 315
# Genenset: Imiquimod-up, Aantal genen: 324
# Genenset: Imiquimod-dn, Aantal genen: 272
# Genenset: Troglitazone-up, Aantal genen: 277
# Genenset: Troglitazone-dn, Aantal genen: 320
# Genenset: 3,3',4,4'-tetrachlorobiphenyl-up, Aantal genen: 277
# Genenset: 3,3',4,4'-tetrachlorobiphenyl-dn, Aantal genen: 321
# Genenset: Puromycin, ec50, 5 d-up, Aantal genen: 107
# Genenset: Puromycin, ec50, 5 d-dn, Aantal genen: 493
# Genenset: Foretinib-up, Aantal genen: 271
# Genenset: Foretinib-dn, Aantal genen: 326
# Genenset: Sirolimus-up, Aantal genen: 431
# Genenset: Sirolimus-dn, Aantal genen: 167
# Genenset: Laminin-up, Aantal genen: 325
# Genenset: Laminin-dn, Aantal genen: 272
# Genenset: Formoterol-up, Aantal genen: 400
# Genenset: Formoterol-dn, Aantal genen: 200
# Genenset: Neocarzinostatin-up, Aantal genen: 293
# Genenset: Neocarzinostatin-dn, Aantal genen: 306
# Genenset: Puromycin, ec50, 1 d-up, Aantal genen: 236
# Genenset: Puromycin, ec50, 1 d-dn, Aantal genen: 364
# Genenset: Puromycin, ec50, 3 d-up, Aantal genen: 263
# Genenset: Puromycin, ec50, 3 d-dn, Aantal genen: 334
# Genenset: Sb 216763-up, Aantal genen: 287
# Genenset: Sb 216763-dn, Aantal genen: 284
# Genenset: Triiodothyronine-[13c6] hydrochloride (t3 thyronine)-up, Aantal genen: 377
# Genenset: Triiodothyronine-[13c6] hydrochloride (t3 thyronine)-dn, Aantal genen: 217
# Genenset: R1881-up, Aantal genen: 291
# Genenset: R1881-dn, Aantal genen: 306
# Genenset: Mk-886-up, Aantal genen: 275
# Genenset: Mk-886-dn, Aantal genen: 322
# Genenset: 1-[3-(trifluoromethyl)phenyl]piperazine-up, Aantal genen: 254
# Genenset: 1-[3-(trifluoromethyl)phenyl]piperazine-dn, Aantal genen: 342
# Genenset: 1-(4-methoxyphenyl)piperazine-up, Aantal genen: 288
# Genenset: 1-(4-methoxyphenyl)piperazine-dn, Aantal genen: 310
# Genenset: Hydrocortisone-up, Aantal genen: 352
# Genenset: Hydrocortisone-dn, Aantal genen: 243
# Genenset: 1-benzylpiperazine-up, Aantal genen: 313
# Genenset: 1-benzylpiperazine-dn, Aantal genen: 283
# Genenset: Sapphyrin pci-2050 (1.25 &icirc;&frac14;m)-up, Aantal genen: 383
# Genenset: Sapphyrin pci-2050 (1.25 &icirc;&frac14;m)-dn, Aantal genen: 213
# Genenset: Sapphyrin pci-2050 (2.5 &icirc;&frac14;m)-up, Aantal genen: 254
# Genenset: Sapphyrin pci-2050 (2.5 &icirc;&frac14;m)-dn, Aantal genen: 341
# Genenset: Pbde 85-up, Aantal genen: 366
# Genenset: Pbde 85-dn, Aantal genen: 229
# Genenset: Heregulin-up, Aantal genen: 244
# Genenset: Heregulin-dn, Aantal genen: 348
# Genenset: L-arginine-up, Aantal genen: 294
# Genenset: L-arginine-dn, Aantal genen: 292
# Genenset: Carboplatin (30 h)-up, Aantal genen: 300
# Genenset: Carboplatin (30 h)-dn, Aantal genen: 297
# Genenset: Carboplatin (24 h)-up, Aantal genen: 228
# Genenset: Carboplatin (24 h)-dn, Aantal genen: 367
# Genenset: Carboplatin (36 h)-up, Aantal genen: 286
# Genenset: Carboplatin (36 h)-dn, Aantal genen: 310
# Genenset: Laccaic acid-up, Aantal genen: 386
# Genenset: Laccaic acid-dn, Aantal genen: 204
# Genenset: Sunitinib-up, Aantal genen: 412
# Genenset: Sunitinib-dn, Aantal genen: 186
# Genenset: Ursodeoxycholic acid-up, Aantal genen: 328
# Genenset: Ursodeoxycholic acid-dn, Aantal genen: 269
# Genenset: 1,25 dihydroxyvitamin d-up, Aantal genen: 361
# Genenset: 1,25 dihydroxyvitamin d-dn, Aantal genen: 237
# Genenset: Hodgkin lymphoma-up, Aantal genen: 289
# Genenset: Hodgkin lymphoma-dn, Aantal genen: 311
# Genenset: 1-piperonylpiperazine-up, Aantal genen: 330
# Genenset: 1-piperonylpiperazine-dn, Aantal genen: 266
# Genenset: Capsaicin-up, Aantal genen: 298
# Genenset: Capsaicin-dn, Aantal genen: 302
# Genenset: Antimony-up, Aantal genen: 355
# Genenset: Antimony-dn, Aantal genen: 244
# Genenset: Telapristone acetate-up, Aantal genen: 309
# Genenset: Telapristone acetate-dn, Aantal genen: 291
# Genenset: Chromium-up, Aantal genen: 335
# Genenset: Chromium-dn, Aantal genen: 265
# Genenset: 1,2,4-benzenetriol-up, Aantal genen: 284
# Genenset: 1,2,4-benzenetriol-dn, Aantal genen: 309
# Genenset: Promegestone-up, Aantal genen: 309
# Genenset: Promegestone-dn, Aantal genen: 291
# Genenset: Testosterone-up, Aantal genen: 244
# Genenset: Testosterone-dn, Aantal genen: 353
# Genenset: Tibolone-up, Aantal genen: 268
# Genenset: Tibolone-dn, Aantal genen: 328
# Genenset: Creatine-up, Aantal genen: 292
# Genenset: Creatine-dn, Aantal genen: 304
# Genenset: Sulforaphane-up, Aantal genen: 319
# Genenset: Sulforaphane-dn, Aantal genen: 281
# Genenset: Calcitonin-up, Aantal genen: 384
# Genenset: Calcitonin-dn, Aantal genen: 211
# Genenset: Y15-up, Aantal genen: 193
# Genenset: Y15-dn, Aantal genen: 407
# Genenset: Temozolomide-up, Aantal genen: 289
# Genenset: Temozolomide-dn, Aantal genen: 311

# %% [markdown]
# Top er zijn stoffen aanwezig. Maar zijn het ook de genen die we hebben? Hiervoor gaan we de genen filteren om te kijken op welke stoffen ze invloed hebben.

# %%
total_hits = 0
relevant_gene_sets = []
for gene_set, genes in drug_file.items():
   present_genes_count =  len([gene for gene in genes if gene in significant_genes.index])
   if present_genes_count > 0:
       relevant_gene_sets.append(gene_set)

   print(f"Gene set: {gene_set}, Present gene count: {present_genes_count}")

   total_hits += present_genes_count

print(f"Total hits: {total_hits}")
print(f"Relevant drugs count:{len(relevant_gene_sets)}")

# %% [markdown]
# Er zijn genen aanwezig. Nu moet hier een netwerk van gemaakt kunnen worden.

# %%
# Maak een lege graaf
G = nx.Graph()

# Voeg genen en medicijnen toe als knopen
for drug, genes in drug_file.items():
    for gene in genes:
        if gene in significant_genes.index:
            G.add_edge(drug, gene)

# Pas node-groottes en labels aan
for node in G.nodes:
    if node in drug_file:  # Node is een medicijn
        G.nodes[node]['size'] = 20
        G.nodes[node]['color'] = 'blue'
        G.nodes[node]['label'] = f"Drug: {node}"
        G.nodes[node]['titel'] = f"Drug: {node}"
    elif node in significant_genes.index:  # Node is een gen
        G.nodes[node]['size'] = 15
        G.nodes[node]['label'] = f"Gene: {node}"
        G.nodes[node]['color'] = 'green'

# Visualiseren
net = Network(notebook=True)  # Als je in Jupyter werkt
net.from_nx(G)  # Converteer NetworkX-graaf naar Pyvis


# Verhoog de labelgrootte en voeg extra opties toe voor de visualisatie
net.set_options("""
var options = {
  "physics": {
    "barnesHut": {
      "gravitationalConstant": -2000,
      "centralGravity": 0.3,
      "springLength": 95,
      "springConstant": 0.04,
      "damping": 0.09
    },
    "minVelocity": 0.75
  },
  "interaction": {
    "hover": true,
    "tooltipDelay": 100,
    "hideEdgesOnDrag": false
  },
  "nodes": {
    "font": {
      "size": 16,
      "face": "arial",
      "align": "center"
    },
    "labelHighlightBold": true
  },
  "background": {
    "color": "rgba(0,0,0,0)"
  },
  "height": "100%",
  "width": "100%"
}
""")



net.show("network.html")
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# network.html
#         <iframe
#             width="100%"
#             height="600px"
#             src="network.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# De blauwe en groene nodes geven respectievelijk medicijnen en genen weer. Indien de namen niet zichtbaar zijn, moet er worden ingezoomd.
#
# In het netwerk is pertuzumab, een kankermedicijn, in HER2-positieve kanker, om precies te zijn. Alleen is het verbonden met het H3F3A-gen, dat eigenlijk helemaal geen directe connectie heeft met HER2. Het H3F3A-gen codeert voor het histoneiwit H3.3, dat door middel van mutaties genomische instabiliteit kan verhogen. Verder dragen de defecte varianten van het H3F3A-gen vaak bij aan agressief kankergedrag, vooral bij bepaalde hersentumoren.
#
# De omgeving kan daardoor ook vrij vergelijkbaar zijn. Maar eerlijk is eerlijk, qua wat er bekend is over een stof zoals pertuzumab, wordt dit niet toegepast op een H3F3A-positieve kanker. Dus dat zal geen nieuwe vondst opleveren.
#
# Dat deze stof en dit gen in de dataset verbonden staan, is de reden waarom deze connectie is ontstaan. Hierdoor is het, denk ik, waardevoller om te kijken naar stoffen die invloed hebben op meerdere genen die verbonden zijn aan bekende kankergenen. Of juist de kankergenen en welke stoffen daarbij horen, zoals cocaïne, die ook in verbinding staat met H3F3A.
#
# Mogelijk kan een andere grotere chemical perturbations-dataset ook al meer inzichten geven, aangezien niet alle genen in de huidige dataset aanwezig zijn.
#
# Want hoe zou het netwerk er dan uit hebben gezien? Zou er dan een 'missing link'-gen of stof tussen het H3F3A-gen en HER2 kunnen liggen? Hoe onwaarschijnlijk dit voorbeeld ook is, met onderzoek is het de kunst om altijd nieuwe, onverwachte vragen te stellen én inzichten te verkrijgen, zelfs als de uitkomsten niet altijd verwacht worden.
#
# En daarom denk ik dat een netwerk zoals deze een stap de goede kant op is. Al is het geen verwacht resultaat, maar het levert wel een antwoord.
